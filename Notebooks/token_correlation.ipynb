# %% [markdown]
# ### Load Joblib

# %%
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the DataFrame
save_path = "/Users/olaoluwatunmise/token-heatmap/Database/df_prices.joblib"
df_prices_loaded = joblib.load(save_path)

print(df_prices_loaded.head())
# Out:
#                            bitcoin     ethereum      solana    ripple
# timestamp
# 2025-07-05 20:00:00  108146.479975  2506.015716  146.923717  2.214030
# 2025-07-05 21:00:00  108114.236164  2506.689296  147.108011  2.210375
# 2025-07-05 22:00:00  108106.831669  2516.540365  147.389401  2.217211
# 2025-07-05 23:00:00  108207.506728  2519.409495  147.898297  2.216587
# 2025-07-06 00:00:00  108216.016211  2516.824669  147.588441  2.217855

# %% [markdown]
# ### Token Correlation Heatmap

# %%
# Calculate the correlation matrix
corr = df_prices_loaded.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Token Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Token Volatility

# %%
# Compute volatility (standard deviation of returns) for each token

# Calculate log returns
returns = df_prices_loaded.pct_change().apply(lambda x: np.log1p(x))

# Compute volatility (standard deviation of log returns)
volatility = returns.std()

print("Volatility for each token:")
print(volatility)
# Out:
# Volatility for each token:
# bitcoin     0.003176
# ethereum    0.006406
# solana      0.006815
# ripple      0.008473
# dtype: float64

# %% [markdown]
# ### Correlation of Tokens Return

# %%
print(returns.head())
# Out:
#                       bitcoin  ethereum    solana    ripple
# timestamp
# 2025-07-05 20:00:00       NaN       NaN       NaN       NaN
# 2025-07-05 21:00:00 -0.000298  0.000269  0.001254 -0.001652
# 2025-07-05 22:00:00 -0.000068  0.003922  0.001911  0.003088
# 2025-07-05 23:00:00  0.000931  0.001139  0.003447 -0.000282
# 2025-07-06 00:00:00  0.000079 -0.001026 -0.002097  0.000572

# %%
# Calculate the correlation matrix
corr = returns.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Token Correlation Heatmap")
plt.show()
